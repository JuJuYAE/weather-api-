# %%
from dotenv import load_dotenv
import os, requests
from telegram import Update
from telegram.ext import ApplicationBuilder, CommandHandler, ContextTypes

# %%
load_dotenv()
# Out:
# True

# %%
token = os.getenv("TELEGRAM_TOKEN")
resp = requests.get(f"https://api.telegram.org/bot{token}/getMe").json()
print(resp)
# Out:
# {'ok': True, 'result': {'id': 8538880142, 'is_bot': True, 'first_name': 'OpenCourt', 'username': 'opencourt_telebot', 'can_join_groups': True, 'can_read_all_group_messages': False, 'supports_inline_queries': False, 'can_connect_to_business': False, 'has_main_web_app': False, 'has_topics_enabled': False}}

# %%
async def start(update, context):
    await update.message.reply_text("Welcome — use /favorites to pick up to 3 courts.")

def main():
    app = ApplicationBuilder().token(token).build()
    app.add_handler(CommandHandler("start", start))
    app.run_polling()

if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File ~/My Python Stuff/Weather API/weather-api-/.venv/lib/python3.9/site-packages/telegram/ext/_application.py:1054, in Application.__run(self, updater_coroutine, stop_signals, bootstrap_retries, close_loop)
#    1053 try:
# -> 1054     loop.run_until_complete(self._bootstrap_initialize(max_retries=bootstrap_retries))
#    1055     if self.post_init:
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/asyncio/base_events.py:618, in BaseEventLoop.run_until_complete(self, future)
#     617 self._check_closed()
# --> 618 self._check_running()
#     620 new_task = not futures.isfuture(future)
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/asyncio/base_events.py:578, in BaseEventLoop._check_running(self)
#     577 if self.is_running():
# --> 578     raise RuntimeError('This event loop is already running')
#     579 if events._get_running_loop() is not None:
#
# RuntimeError: This event loop is already running
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# File ~/My Python Stuff/Weather API/weather-api-/.venv/lib/python3.9/site-packages/telegram/ext/_application.py:1079, in Application.__run(self, updater_coroutine, stop_signals, bootstrap_retries, close_loop)
#    1078         loop.run_until_complete(self.post_stop(self))
# -> 1079 loop.run_until_complete(self.shutdown())
#    1080 if self.post_shutdown:
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/asyncio/base_events.py:618, in BaseEventLoop.run_until_complete(self, future)
#     617 self._check_closed()
# --> 618 self._check_running()
#     620 new_task = not futures.isfuture(future)
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/asyncio/base_events.py:578, in BaseEventLoop._check_running(self)
#     577 if self.is_running():
# --> 578     raise RuntimeError('This event loop is already running')
#     579 if events._get_running_loop() is not None:
#
# RuntimeError: This event loop is already running
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[9], line 10
#       7     app.run_polling()
#       9 if __name__ == "__main__":
# ---> 10     main()
#
# Cell In[9], line 7, in main()
#       5 app = ApplicationBuilder().token(token).build()
#       6 app.add_handler(CommandHandler("start", start))
# ----> 7 app.run_polling()
#
# File ~/My Python Stuff/Weather API/weather-api-/.venv/lib/python3.9/site-packages/telegram/ext/_application.py:839, in Application.run_polling(self, poll_interval, timeout, bootstrap_retries, allowed_updates, drop_pending_updates, close_loop, stop_signals)
#     836 def error_callback(exc: TelegramError) -> None:
#     837     self.create_task(self.process_error(error=exc, update=None))
# --> 839 return self.__run(
#     840     updater_coroutine=self.updater.start_polling(
#     841         poll_interval=poll_interval,
#     842         timeout=timeout,
#     843         bootstrap_retries=bootstrap_retries,
#     844         allowed_updates=allowed_updates,
#     845         drop_pending_updates=drop_pending_updates,
#     846         error_callback=error_callback,  # if there is an error in fetching updates
#     847     ),
#     848     stop_signals=stop_signals,
#     849     bootstrap_retries=bootstrap_retries,
#     850     close_loop=close_loop,
#     851 )
#
# File ~/My Python Stuff/Weather API/weather-api-/.venv/lib/python3.9/site-packages/telegram/ext/_application.py:1084, in Application.__run(self, updater_coroutine, stop_signals, bootstrap_retries, close_loop)
#    1082 finally:
#    1083     if close_loop:
# -> 1084         loop.close()
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/asyncio/unix_events.py:58, in _UnixSelectorEventLoop.close(self)
#      57 def close(self):
# ---> 58     super().close()
#      59     if not sys.is_finalizing():
#      60         for sig in list(self._signal_handlers):
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/asyncio/selector_events.py:89, in BaseSelectorEventLoop.close(self)
#      87 def close(self):
#      88     if self.is_running():
# ---> 89         raise RuntimeError("Cannot close a running event loop")
#      90     if self.is_closed():
#      91         return
#
# RuntimeError: Cannot close a running event loop
